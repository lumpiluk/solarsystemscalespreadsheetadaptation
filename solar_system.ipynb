# %% [markdown]
# # Scale of the Solar System
#
# This is an adaptation of [Phil Plait](https://twitter.com/BadAstronomer)'s Solar System Scale [spreadsheet](https://docs.google.com/spreadsheets/d/1m6-SH0mShxxSnHFVYERLw9J7ajs0GftG54QdRuI69hc) presented in an article at [Syfy](http://www.syfy.com/syfywire/scaling-the-solar-system).
#
# You can find the runnable Jupyter notebook from which this page was created on [Github](https://github.com/lumpiluk/solarsystemscalespreadsheetadaptation).

# %%
import math
import pandas as pd


AU = 149597870700  # astronomical unit
LY = 9.4607e15  # light-year


def format_distance(distance):
    """Make long distances given in meters a little more readable."""
    if isinstance(distance, str):
        return distance  # In this case distance probably isn't actually a distance.
    if distance == 0:
        return "0 m"  # Would be covered by log10(d) < 3, but log10(0) throws an error.
    if math.log10(distance) < -3:
        return "{:,.2f} μm".format(distance * 10 ** 6)
    if math.log10(distance) < -2:
        return "{:,.2f} mm".format(distance * 10 ** 3)
    if math.log10(distance) < 0:
        return "{:,.2f} cm".format(distance * 10 ** 2)
    if math.log10(distance) < 3:
        return "{:,.2f} m".format(distance)
    if distance < AU:
        return "{:,.2f} km".format(distance * 10 ** -3)
    if distance < LY:
        return "{:,.2f} AU".format(distance / AU)
    return "{:,.2f} ly".format(distance / LY)


print("All distances in meters!")
r_sol = 695000000
solar_system = pd.DataFrame(data={
    'object': ["Sun", "Mercury", "Venus", "Earth", "Mars", "Jupiter", "Saturn",
               "Uranus", "Neptune", "Pluto", "Kuiper Belt inner edge",
               "Kuiper Belt outer edge", "Alpha Centauri"],
    'radius': [r_sol, 2440000, 6052000, 6378000, 3397000, 71492000,
               60268000, 25559000, 24766000, 1150000, 0, 0, 1.22 * r_sol],
    'distance_from_sun': [0., 5.79e+10, 1.08e+11, 1.5e+11, 2.28e+11, 7.78e+11,
                          1.43e+12, 2.87e+12, 4.5e+12, 5.91e+12, 4.5e+12,
                          7.5e+12, 4.07e+16]
})

# Reorder columns because Python dicts aren't sorted by keys:
solar_system = solar_system[['object', 'radius', 'distance_from_sun']]

solar_system.style.format(format_distance)
# Out:
# All distances in meters!
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   object
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   radius
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   distance_from_sun
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row0" rowspan=1>
#                     0
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row0_col0"
#                  class="data row0 col0" >
#                     Sun
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row0_col1"
#                  class="data row0 col1" >
#                     695,000.00 km
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row0_col2"
#                  class="data row0 col2" >
#                     0 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row1" rowspan=1>
#                     1
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row1_col0"
#                  class="data row1 col0" >
#                     Mercury
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row1_col1"
#                  class="data row1 col1" >
#                     2,440.00 km
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row1_col2"
#                  class="data row1 col2" >
#                     57,900,000.00 km
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row2" rowspan=1>
#                     2
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row2_col0"
#                  class="data row2 col0" >
#                     Venus
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row2_col1"
#                  class="data row2 col1" >
#                     6,052.00 km
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row2_col2"
#                  class="data row2 col2" >
#                     108,000,000.00 km
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row3" rowspan=1>
#                     3
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row3_col0"
#                  class="data row3 col0" >
#                     Earth
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row3_col1"
#                  class="data row3 col1" >
#                     6,378.00 km
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row3_col2"
#                  class="data row3 col2" >
#                     1.00 AU
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row4" rowspan=1>
#                     4
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row4_col0"
#                  class="data row4 col0" >
#                     Mars
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row4_col1"
#                  class="data row4 col1" >
#                     3,397.00 km
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row4_col2"
#                  class="data row4 col2" >
#                     1.52 AU
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row5" rowspan=1>
#                     5
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row5_col0"
#                  class="data row5 col0" >
#                     Jupiter
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row5_col1"
#                  class="data row5 col1" >
#                     71,492.00 km
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row5_col2"
#                  class="data row5 col2" >
#                     5.20 AU
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row6" rowspan=1>
#                     6
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row6_col0"
#                  class="data row6 col0" >
#                     Saturn
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row6_col1"
#                  class="data row6 col1" >
#                     60,268.00 km
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row6_col2"
#                  class="data row6 col2" >
#                     9.56 AU
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row7" rowspan=1>
#                     7
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row7_col0"
#                  class="data row7 col0" >
#                     Uranus
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row7_col1"
#                  class="data row7 col1" >
#                     25,559.00 km
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row7_col2"
#                  class="data row7 col2" >
#                     19.18 AU
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row8" rowspan=1>
#                     8
#
#
#
#                 <td id="T_a47a80f2_fd63_11e7_b18f_5fce9d87fcb3row8_col0"
#                  class="data row8 col0" >

# %%
def scale_solar_system(new_diameter=.1, reference_object='Sun'):
    """Scale the solar system in reference to one of the available celestial bodies.
    
    Args:
        new_diameter (float): New size of the referenze object in meters. Default: 0.1 meters for the Sun.
        reference_object: Reference object to scale. Must be either of the following:
            "Sun", "Mercury", "Venus", "Earth", "Mars", "Jupiter", "Saturn",
            "Uranus", "Neptune", "Pluto", "Kuiper Belt inner edge",
            "Kuiper Belt outer edge", "Alpha Centauri".
            Default: "Sun"
    
    Returns:
        Pandas DataFrame containing the original scales of the solar system in the columns
        'object', 'radius', and 'distance_from_sun', as well as the scaled distances for
        'unit_radius', 'unit_distance_from_sun', 'radius_scaled', 'diameter_scaled', and
        'distance_from_sun_scaled'.
        
        If reference_object is "Sun", then for the Sun unit_radius will be equal to 1.0.
        unit_distance_from_sun is distance from sun in therms of the radius of the reference_object.
    """
    scaled = solar_system.copy()
    reference_object_radius = scaled[scaled['object'] == reference_object]['radius'].values[0]
    scaled['unit_radius'] = scaled['radius'] / reference_object_radius
    scaled['unit_distance_from_sun'] = scaled['distance_from_sun'] / reference_object_radius
    scaled['radius_scaled'] = scaled['unit_radius'] * new_diameter / 2
    scaled['diameter_scaled'] = scaled['radius_scaled'] * 2
    scaled['distance_from_sun_scaled'] = scaled['unit_distance_from_sun'] * new_diameter / 2
    return scaled


def show_scaled_with_jupyter(scaled):
    return scaled[['object', 'diameter_scaled', 'distance_from_sun_scaled']].style.format(format_distance)

# %% [markdown]
# ## Now we can scale the solar system in any way we want!

# %%
sss_sun = scale_solar_system(new_diameter=.1, reference_object='Sun')
show_scaled_with_jupyter(sss_sun)
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   object
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   diameter_scaled
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   distance_from_sun_scaled
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row0" rowspan=1>
#                     0
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row0_col0"
#                  class="data row0 col0" >
#                     Sun
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row0_col1"
#                  class="data row0 col1" >
#                     10.00 cm
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row0_col2"
#                  class="data row0 col2" >
#                     0 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row1" rowspan=1>
#                     1
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row1_col0"
#                  class="data row1 col0" >
#                     Mercury
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row1_col1"
#                  class="data row1 col1" >
#                     351.08 μm
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row1_col2"
#                  class="data row1 col2" >
#                     4.17 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row2" rowspan=1>
#                     2
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row2_col0"
#                  class="data row2 col0" >
#                     Venus
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row2_col1"
#                  class="data row2 col1" >
#                     870.79 μm
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row2_col2"
#                  class="data row2 col2" >
#                     7.77 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row3" rowspan=1>
#                     3
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row3_col0"
#                  class="data row3 col0" >
#                     Earth
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row3_col1"
#                  class="data row3 col1" >
#                     917.70 μm
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row3_col2"
#                  class="data row3 col2" >
#                     10.79 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row4" rowspan=1>
#                     4
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row4_col0"
#                  class="data row4 col0" >
#                     Mars
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row4_col1"
#                  class="data row4 col1" >
#                     488.78 μm
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row4_col2"
#                  class="data row4 col2" >
#                     16.40 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row5" rowspan=1>
#                     5
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row5_col0"
#                  class="data row5 col0" >
#                     Jupiter
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row5_col1"
#                  class="data row5 col1" >
#                     1.03 cm
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row5_col2"
#                  class="data row5 col2" >
#                     55.97 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row6" rowspan=1>
#                     6
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row6_col0"
#                  class="data row6 col0" >
#                     Saturn
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row6_col1"
#                  class="data row6 col1" >
#                     8.67 mm
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row6_col2"
#                  class="data row6 col2" >
#                     102.88 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row7" rowspan=1>
#                     7
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row7_col0"
#                  class="data row7 col0" >
#                     Uranus
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row7_col1"
#                  class="data row7 col1" >
#                     3.68 mm
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row7_col2"
#                  class="data row7 col2" >
#                     206.47 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row8" rowspan=1>
#                     8
#
#
#
#                 <td id="T_5df03e28_fd64_11e7_b18f_5fce9d87fcb3row8_col0"
#                  class="data row8 col0" >
#                     Neptune

# %% [markdown]
# ### What if the *Earth* Were the Size of a *Marble*?

# %%
sss_earth_marble = scale_solar_system(new_diameter=.01, reference_object='Earth')
show_scaled_with_jupyter(sss_earth_marble)
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   object
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   diameter_scaled
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   distance_from_sun_scaled
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row0" rowspan=1>
#                     0
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row0_col0"
#                  class="data row0 col0" >
#                     Sun
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row0_col1"
#                  class="data row0 col1" >
#                     1.09 m
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row0_col2"
#                  class="data row0 col2" >
#                     0 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row1" rowspan=1>
#                     1
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row1_col0"
#                  class="data row1 col0" >
#                     Mercury
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row1_col1"
#                  class="data row1 col1" >
#                     3.83 mm
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row1_col2"
#                  class="data row1 col2" >
#                     45.39 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row2" rowspan=1>
#                     2
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row2_col0"
#                  class="data row2 col0" >
#                     Venus
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row2_col1"
#                  class="data row2 col1" >
#                     9.49 mm
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row2_col2"
#                  class="data row2 col2" >
#                     84.67 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row3" rowspan=1>
#                     3
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row3_col0"
#                  class="data row3 col0" >
#                     Earth
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row3_col1"
#                  class="data row3 col1" >
#                     1.00 cm
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row3_col2"
#                  class="data row3 col2" >
#                     117.59 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row4" rowspan=1>
#                     4
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row4_col0"
#                  class="data row4 col0" >
#                     Mars
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row4_col1"
#                  class="data row4 col1" >
#                     5.33 mm
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row4_col2"
#                  class="data row4 col2" >
#                     178.74 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row5" rowspan=1>
#                     5
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row5_col0"
#                  class="data row5 col0" >
#                     Jupiter
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row5_col1"
#                  class="data row5 col1" >
#                     11.21 cm
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row5_col2"
#                  class="data row5 col2" >
#                     609.91 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row6" rowspan=1>
#                     6
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row6_col0"
#                  class="data row6 col0" >
#                     Saturn
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row6_col1"
#                  class="data row6 col1" >
#                     9.45 cm
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row6_col2"
#                  class="data row6 col2" >
#                     1.12 km
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row7" rowspan=1>
#                     7
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row7_col0"
#                  class="data row7 col0" >
#                     Uranus
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row7_col1"
#                  class="data row7 col1" >
#                     4.01 cm
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row7_col2"
#                  class="data row7 col2" >
#                     2.25 km
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row8" rowspan=1>
#                     8
#
#
#
#                 <td id="T_5fd0ce6a_fd64_11e7_b18f_5fce9d87fcb3row8_col0"
#                  class="data row8 col0" >
#                     Neptune

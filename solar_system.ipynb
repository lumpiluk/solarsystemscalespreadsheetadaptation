# %% [markdown]
# # Scale of the Solar System
#
# This is an adaptation of [Phil Plait](https://twitter.com/BadAstronomer)'s Solar System Scale [spreadsheet](https://docs.google.com/spreadsheets/d/1m6-SH0mShxxSnHFVYERLw9J7ajs0GftG54QdRuI69hc) presented in an article at [Syfy](http://www.syfy.com/syfywire/scaling-the-solar-system).
#
# You can find the runnable Jupyter notebook from which this page was created on [Github](https://github.com/lumpiluk/solarsystemscalespreadsheetadaptation).

# %%
import math
import pandas as pd


# All distances in meters!

AU = 149597870700  # astronomical unit
LY = 9.4607e15  # light-year
R_SOL = 695000000  # radius of the Sun


def format_distance(distance):
    """Make long distances given in meters a little more readable."""
    if isinstance(distance, str):
        # In this case distance probably isn't actually a distance.
        return distance
    if distance == 0:
        # Would be covered by log10(d) < 3, but log10(0) throws an error.
        return "0 m"
    if math.log10(distance) < -6:
        return "{:,.3e} nm".format(distance * 10 ** 9)
    if math.log10(distance) < -3:
        return "{:,.2f} μm".format(distance * 10 ** 6)
    if math.log10(distance) < -2:
        return "{:,.2f} mm".format(distance * 10 ** 3)
    if math.log10(distance) < 0:
        return "{:,.2f} cm".format(distance * 10 ** 2)
    if math.log10(distance) < 3:
        return "{:,.2f} m".format(distance)
    if math.log10(distance) < 6:
        return "{:,.2f} km".format(distance * 10 ** -3)
    if math.log10(distance) < 9:
        return "{:,.2f} Mm".format(distance * 10 ** -6)
    if distance < AU:
        return "{:,.2f} Gm".format(distance * 10 ** -9)
    if distance < LY:
        return "{:,.2f} AU".format(distance / AU)
    return "{:,.2f} ly".format(distance / LY)


solar_system = pd.DataFrame(data={
    'object': [
        "Sun",
        "Mercury",
        "Venus",
        "Earth",
        "Mars",
        "Jupiter",
        "Saturn",
        "Uranus",
        "Neptune",
        "Pluto",
        "Kuiper Belt inner edge",
        "Kuiper Belt outer edge",
        "Alpha Centauri"
    ],
    'radius': [
        R_SOL,  # Sun
        2440000,  # Mercury
        6052000,  # Venus
        6378000,  # Earth
        3397000,  # Mars
        71492000,  # Jupiter
        60268000,  # Saturn
        25559000,  # Uranus
        24766000,  # Neptune
        1150000,  # Pluto
        0,  # Kuiper Belt inner edge
        0,  # Kuiper Belt outer edge
        1.22 * R_SOL  # Alpha Centauri
    ],
    'distance_from_sun': [
        0.,  # Sun
        5.79e+10,  # Mercury
        1.08e+11,  # Venus
        1.5e+11,  # Earth
        2.28e+11,  # Mars
        7.78e+11,  # Jupiter
        1.43e+12,  # Saturn
        2.87e+12,  # Uranus
        4.5e+12,  # Neptune
        5.91e+12,  # Pluto
        4.5e+12,  # Kuiper Belt inner edge
        7.5e+12,  # Kuiper Belt outer edge
        4.07e+16  # Alpha Centauri
    ]
})
solar_system['diameter'] = solar_system['radius'] * 2

# Reorder columns because Python dicts aren't sorted by keys:
solar_system = solar_system[['object', 'radius', 'diameter',
                             'distance_from_sun']]

solar_system.style.format(format_distance)
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   object
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   radius
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   diameter
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   distance_from_sun
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row0" rowspan=1>
#                     0
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row0_col0"
#                  class="data row0 col0" >
#                     Sun
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row0_col1"
#                  class="data row0 col1" >
#                     695.00 Mm
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row0_col2"
#                  class="data row0 col2" >
#                     1.39 Gm
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row0_col3"
#                  class="data row0 col3" >
#                     0 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row1" rowspan=1>
#                     1
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row1_col0"
#                  class="data row1 col0" >
#                     Mercury
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row1_col1"
#                  class="data row1 col1" >
#                     2.44 Mm
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row1_col2"
#                  class="data row1 col2" >
#                     4.88 Mm
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row1_col3"
#                  class="data row1 col3" >
#                     57.90 Gm
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row2" rowspan=1>
#                     2
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row2_col0"
#                  class="data row2 col0" >
#                     Venus
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row2_col1"
#                  class="data row2 col1" >
#                     6.05 Mm
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row2_col2"
#                  class="data row2 col2" >
#                     12.10 Mm
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row2_col3"
#                  class="data row2 col3" >
#                     108.00 Gm
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row3" rowspan=1>
#                     3
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row3_col0"
#                  class="data row3 col0" >
#                     Earth
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row3_col1"
#                  class="data row3 col1" >
#                     6.38 Mm
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row3_col2"
#                  class="data row3 col2" >
#                     12.76 Mm
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row3_col3"
#                  class="data row3 col3" >
#                     1.00 AU
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row4" rowspan=1>
#                     4
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row4_col0"
#                  class="data row4 col0" >
#                     Mars
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row4_col1"
#                  class="data row4 col1" >
#                     3.40 Mm
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row4_col2"
#                  class="data row4 col2" >
#                     6.79 Mm
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row4_col3"
#                  class="data row4 col3" >
#                     1.52 AU
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row5" rowspan=1>
#                     5
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row5_col0"
#                  class="data row5 col0" >
#                     Jupiter
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row5_col1"
#                  class="data row5 col1" >
#                     71.49 Mm
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row5_col2"
#                  class="data row5 col2" >
#                     142.98 Mm
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row5_col3"
#                  class="data row5 col3" >
#                     5.20 AU
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row6" rowspan=1>
#                     6
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row6_col0"
#                  class="data row6 col0" >
#                     Saturn
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row6_col1"
#                  class="data row6 col1" >
#                     60.27 Mm
#
#
#
#                 <td id="T_4969f34e_fdce_11e7_b18f_5fce9d87fcb3row6_col2"
#                  class="data row6 col2" >
#                     120.54 Mm

# %%
def scale_solar_system(
        new_size=.1,
        reference='radius',
        reference_object='Sun'):
    """Scale the solar system in reference to the selected
    reference property of one of the available celestial bodies.
    
    Args:
        new_size (float): New size of the object's reference
            property in meters.            
            Default: 0.1 meters for the Sun.
        reference (str): What to scale.
            Must be either of the following:
            'radius', 'diameter', 'distance_from_sun', or
            some other numerical column previously added to
            the solar_system DataFrame.
            Default: 'radius'
        reference_object (str): Reference object for the new size.
            Must be either of the following:
            "Sun", "Mercury", "Venus", "Earth", "Mars", "Jupiter",
            "Saturn", "Uranus", "Neptune", "Pluto",
            "Kuiper Belt inner edge", "Kuiper Belt outer edge",
            "Alpha Centauri".
            Default: "Sun"
    
    Returns:
        Pandas DataFrame containing the original scales of the solar
        system in the columns 'object', 'radius', and
        'distance_from_sun', as well as the scaled distances for
        'radius_scaled', 'diameter_scaled', and
        'distance_from_sun_scaled'.
    """
    s = solar_system.copy()
    
    original_size = (s[s['object'] ==
        reference_object][reference].values[0])
    scale_factor = new_size / original_size
    
    s['radius_scaled'] = s['radius'] * scale_factor
    s['diameter_scaled'] = s['radius_scaled'] * 2
    s['distance_from_sun_scaled'] = s['distance_from_sun'] * scale_factor
    
    return s


def show_scaled_with_jupyter(scaled):
    return (scaled[['object', 'radius_scaled', 'diameter_scaled',
                    'distance_from_sun_scaled']]
            .style
            .format(format_distance))

# %% [markdown]
# ## Now we can scale the solar system in any way we want!

# %%
# Scale the solar system such that the Sun has a diameter of 10 cm.
sss_sun = scale_solar_system(
    new_size=.1,
    reference='diameter',
    reference_object='Sun'
)
show_scaled_with_jupyter(sss_sun)
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   object
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   radius_scaled
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   diameter_scaled
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   distance_from_sun_scaled
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row0" rowspan=1>
#                     0
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row0_col0"
#                  class="data row0 col0" >
#                     Sun
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row0_col1"
#                  class="data row0 col1" >
#                     5.00 cm
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row0_col2"
#                  class="data row0 col2" >
#                     10.00 cm
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row0_col3"
#                  class="data row0 col3" >
#                     0 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row1" rowspan=1>
#                     1
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row1_col0"
#                  class="data row1 col0" >
#                     Mercury
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row1_col1"
#                  class="data row1 col1" >
#                     175.54 μm
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row1_col2"
#                  class="data row1 col2" >
#                     351.08 μm
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row1_col3"
#                  class="data row1 col3" >
#                     4.17 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row2" rowspan=1>
#                     2
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row2_col0"
#                  class="data row2 col0" >
#                     Venus
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row2_col1"
#                  class="data row2 col1" >
#                     435.40 μm
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row2_col2"
#                  class="data row2 col2" >
#                     870.79 μm
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row2_col3"
#                  class="data row2 col3" >
#                     7.77 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row3" rowspan=1>
#                     3
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row3_col0"
#                  class="data row3 col0" >
#                     Earth
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row3_col1"
#                  class="data row3 col1" >
#                     458.85 μm
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row3_col2"
#                  class="data row3 col2" >
#                     917.70 μm
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row3_col3"
#                  class="data row3 col3" >
#                     10.79 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row4" rowspan=1>
#                     4
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row4_col0"
#                  class="data row4 col0" >
#                     Mars
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row4_col1"
#                  class="data row4 col1" >
#                     244.39 μm
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row4_col2"
#                  class="data row4 col2" >
#                     488.78 μm
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row4_col3"
#                  class="data row4 col3" >
#                     16.40 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row5" rowspan=1>
#                     5
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row5_col0"
#                  class="data row5 col0" >
#                     Jupiter
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row5_col1"
#                  class="data row5 col1" >
#                     5.14 mm
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row5_col2"
#                  class="data row5 col2" >
#                     1.03 cm
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row5_col3"
#                  class="data row5 col3" >
#                     55.97 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row6" rowspan=1>
#                     6
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row6_col0"
#                  class="data row6 col0" >
#                     Saturn
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row6_col1"
#                  class="data row6 col1" >
#                     4.34 mm
#
#
#
#                 <td id="T_f54e0b60_fdcd_11e7_b18f_5fce9d87fcb3row6_col2"
#                  class="data row6 col2" >
#                     8.67 mm

# %% [markdown]
# ### What if the Earth Were the Size of a Marble?

# %%
sss_earth_marble = scale_solar_system(
    new_size=.01,
    reference='diameter',
    reference_object='Earth'
)
show_scaled_with_jupyter(sss_earth_marble)
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   object
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   radius_scaled
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   diameter_scaled
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   distance_from_sun_scaled
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row0" rowspan=1>
#                     0
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row0_col0"
#                  class="data row0 col0" >
#                     Sun
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row0_col1"
#                  class="data row0 col1" >
#                     54.48 cm
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row0_col2"
#                  class="data row0 col2" >
#                     1.09 m
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row0_col3"
#                  class="data row0 col3" >
#                     0 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row1" rowspan=1>
#                     1
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row1_col0"
#                  class="data row1 col0" >
#                     Mercury
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row1_col1"
#                  class="data row1 col1" >
#                     1.91 mm
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row1_col2"
#                  class="data row1 col2" >
#                     3.83 mm
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row1_col3"
#                  class="data row1 col3" >
#                     45.39 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row2" rowspan=1>
#                     2
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row2_col0"
#                  class="data row2 col0" >
#                     Venus
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row2_col1"
#                  class="data row2 col1" >
#                     4.74 mm
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row2_col2"
#                  class="data row2 col2" >
#                     9.49 mm
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row2_col3"
#                  class="data row2 col3" >
#                     84.67 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row3" rowspan=1>
#                     3
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row3_col0"
#                  class="data row3 col0" >
#                     Earth
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row3_col1"
#                  class="data row3 col1" >
#                     5.00 mm
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row3_col2"
#                  class="data row3 col2" >
#                     1.00 cm
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row3_col3"
#                  class="data row3 col3" >
#                     117.59 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row4" rowspan=1>
#                     4
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row4_col0"
#                  class="data row4 col0" >
#                     Mars
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row4_col1"
#                  class="data row4 col1" >
#                     2.66 mm
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row4_col2"
#                  class="data row4 col2" >
#                     5.33 mm
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row4_col3"
#                  class="data row4 col3" >
#                     178.74 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row5" rowspan=1>
#                     5
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row5_col0"
#                  class="data row5 col0" >
#                     Jupiter
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row5_col1"
#                  class="data row5 col1" >
#                     5.60 cm
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row5_col2"
#                  class="data row5 col2" >
#                     11.21 cm
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row5_col3"
#                  class="data row5 col3" >
#                     609.91 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row6" rowspan=1>
#                     6
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row6_col0"
#                  class="data row6 col0" >
#                     Saturn
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row6_col1"
#                  class="data row6 col1" >
#                     4.72 cm
#
#
#
#                 <td id="T_f6f8219e_fdcd_11e7_b18f_5fce9d87fcb3row6_col2"
#                  class="data row6 col2" >
#                     9.45 cm

# %% [markdown]
# ### What if Mars Were at an Average Distance of 1 m From the Sun?

# %%
sss_mars_distance = scale_solar_system(
    new_size=1,
    reference='distance_from_sun',
    reference_object='Mars'
)
show_scaled_with_jupyter(sss_mars_distance)
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   object
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   radius_scaled
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   diameter_scaled
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   distance_from_sun_scaled
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row0" rowspan=1>
#                     0
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row0_col0"
#                  class="data row0 col0" >
#                     Sun
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row0_col1"
#                  class="data row0 col1" >
#                     3.05 mm
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row0_col2"
#                  class="data row0 col2" >
#                     6.10 mm
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row0_col3"
#                  class="data row0 col3" >
#                     0 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row1" rowspan=1>
#                     1
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row1_col0"
#                  class="data row1 col0" >
#                     Mercury
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row1_col1"
#                  class="data row1 col1" >
#                     10.70 μm
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row1_col2"
#                  class="data row1 col2" >
#                     21.40 μm
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row1_col3"
#                  class="data row1 col3" >
#                     25.39 cm
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row2" rowspan=1>
#                     2
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row2_col0"
#                  class="data row2 col0" >
#                     Venus
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row2_col1"
#                  class="data row2 col1" >
#                     26.54 μm
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row2_col2"
#                  class="data row2 col2" >
#                     53.09 μm
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row2_col3"
#                  class="data row2 col3" >
#                     47.37 cm
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row3" rowspan=1>
#                     3
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row3_col0"
#                  class="data row3 col0" >
#                     Earth
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row3_col1"
#                  class="data row3 col1" >
#                     27.97 μm
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row3_col2"
#                  class="data row3 col2" >
#                     55.95 μm
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row3_col3"
#                  class="data row3 col3" >
#                     65.79 cm
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row4" rowspan=1>
#                     4
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row4_col0"
#                  class="data row4 col0" >
#                     Mars
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row4_col1"
#                  class="data row4 col1" >
#                     14.90 μm
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row4_col2"
#                  class="data row4 col2" >
#                     29.80 μm
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row4_col3"
#                  class="data row4 col3" >
#                     100.00 cm
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row5" rowspan=1>
#                     5
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row5_col0"
#                  class="data row5 col0" >
#                     Jupiter
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row5_col1"
#                  class="data row5 col1" >
#                     313.56 μm
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row5_col2"
#                  class="data row5 col2" >
#                     627.12 μm
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row5_col3"
#                  class="data row5 col3" >
#                     3.41 m
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3"
#                  class="row_heading level0 row6" rowspan=1>
#                     6
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row6_col0"
#                  class="data row6 col0" >
#                     Saturn
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row6_col1"
#                  class="data row6 col1" >
#                     264.33 μm
#
#
#
#                 <td id="T_f6f8219f_fdcd_11e7_b18f_5fce9d87fcb3row6_col2"
#                  class="data row6 col2" >
#                     528.67 μm
